# %% [markdown]
# # "Chill Havana" Project
# ### Análisis de Bares y Restaurantes en La Habana

# %% [markdown]
# Un día como cualquier otro salía un grupo de jóvenes de su escuela tras haber terminado los parciales con ganas de pasar un ratico chill con los colegas, con algo para picar y una musiquita de fondo fuera de la monotonía de sus casas. Ya todos habían dado el sí cuando alguien soltó la misma pregunta de siempre: Loco, pero a dónde vamos? Nada, que esa era la pregunta que casi siemmpre cortaba todo el rollo. Buscar el sitio ideal para las vibes del momento era bastante complicado, en ningún sitio ponían toda la info necearia. "Tu busca en MenúCuba, ella en Instagram y yo la dirección en Maps, y ojala salga todo!"

# %% [markdown]
# Nunca has sentido tremendo agobio de escoger a que lugar salir? Pues aquellos jovenes si y decidieron que era la ultima vez. Que es lo mas importante para a la hora de elegir? La variedad del menu o un plato especifico? La ubicacion? La valoracion de otras personas?
# Nada, que tu puedes elegir lo que quieras porque para eso aquella tarde nacio el proyecto "Chill Havana".

# %% [markdown]
# Tanto lio y al final ese dia no salieron, se quedaron pensando y organizando sus ideas. Si si, ellos se tomaron el problema como algo personal, pero tranqui, tenian su arma secreta: Jorge, el amiguito del grupo que le metia al HTML. Estaba clarisimo, querian hacer una pagina web que recopilara datos sobre mas de 200 bares y restaurantes de La Habana para que cualquiera que quisiera elegir un lugar pudiera encontrar alli todo lo necesario para decidirse por el mas adecuado para la ocasion.
# Oye que el proyecto era tremenda idea eh, como crees que cambiaria tu experiencia al salir a comer tener un sitio web tan duro?

# %% [markdown]
# Despues de meses de arduo trabajo (en serio fue tremenda pincha) el grupito decidio analizar sus hallazgos.

# %%
#Crear el dataframe con los json para el trabajo con las bibliotecas de Python
import glob
import json
import pandas as pd
import matplotlib.pyplot as plt
import folium
import plotly.express as px

def crear_data_frame():
    ruta = "C:/Users/andre/Desktop/Chill_Havana_Project/Jsons"
    data = []
    for archivo in glob.glob(ruta + "/*.json"):
        with open(archivo, 'r', encoding='utf-8') as f:
            contenido = json.load(f)
            data.append(contenido)
            
    df = pd.DataFrame(data)
    return df

df = crear_data_frame()
print(df)
# Out:
#     type_of_establishment              name                district  \
# 0             restaurante          28 y Mar                   Playa
# 1             restaurante              2KFÉ                   Regla
# 2       bar - restaurante        5ta Billar                   Regla
# 3             restaurante     A&J Fast Food                Marianao
# 4             restaurante      Abuelo D'Oro                 Boyeros
# ..                    ...               ...                     ...
# 193           restaurante    Cafe Versalles              Guanabacoa
# 194     bar - restaurante         Villarino                   Playa
# 195     bar - restaurante        Vita Nuova  Plaza de la Revolución
# 196           restaurante              Wapa  Plaza de la Revolución
# 197     bar - restaurante  Yesterday Havana   San Miguel del Padrón
#
#                                            coordinates  \
# 0    {'latitude': 23.12361712886297, 'longitude': -...
# 1    {'latitude': 23.12805874474967, 'longitude': -...
# 2    {'latitude': 23.12374503719618, 'longitude': -...
# 3    {'latitude': 23.07275737968528, 'longitude': -...
# 4    {'latitude': 23.057838724569645, 'longitude': ...
# ..                                                 ...
# 193  {'latitude': 23.125381234140697, 'longitude': ...
# 194  {'latitude': 23.10341935595807, 'longitude': -...
# 195  {'latitude': 23.140886322733916, 'longitude': ...
# 196  {'latitude': 23.133054069126786, 'longitude': ...
# 197  {'latitude': 23.099170645364698, 'longitude': ...
#
#                                                contact  \
# 0    {'phone_number': '72125013', 'e-mail': False, ...
# 1    {'phone_number': False, 'e-mail': False, 'web_...
# 2    {'phone_number': False, 'e-mail': False, 'web_...
# 3    {'phone_number': False, 'e-mail': False, 'web_...
# 4    {'phone_number': '76472100', 'e-mail': False, ...
# ..                                                 ...
# 193  {'phone_number': False, 'e-mail': False, 'web_...
# 194  {'phone_number': '72077867', 'e-mail': False, ...
# 195  {'phone_number': '78329774', 'e-mail': False, ...
# 196  {'phone_number': '78314553', 'e-mail': 'info@w...
# 197  {'phone_number': '76930649', 'e-mail': False, ...
#
#                                               schedule  rating  \
# 0    {'monday': {'open': '0830', 'close': '2400'}, ...     3.8
# 1    {'monday': {'open': '1000', 'close': '2000'}, ...     5.0
# 2    {'monday': {'open': '1300', 'close': '0100'}, ...     4.8
# 3    {'monday': {'open': '0900', 'close': '2300'}, ...     NaN
# 4    {'monday': {'open': '1130', 'close': '2330'}, ...     5.0
# ..                                                 ...     ...
# 193  {'monday': {'open': '0900', 'close': '2400'}, ...     5.0
# 194  {'monday': {'open': '1200', 'close': '2200'}, ...     5.0
# 195  {'monday': {'open': '1100', 'close': '2400'}, ...     5.0
# 196  {'monday': {'open': '1130', 'close': '2300'}, ...     3.5
# 197  {'monday': {'open': False, 'close': False}, 't...     4.5
#
#     intake_capacity                        cuisine  \
# 0              alta        [internacional, cubana]
# 1              baja             [cubana, mexicana]
# 2             media           [cocteleria, cubana]
# 3              baja                [internacional]
# 4              alta       [criolla, internacional]
# ..              ...                            ...
# 193            baja             [cubana, italiana]
# 194            alta            [criolla, italiana]
# 195           media   [italiana, cubana, caribeña]
# 196           media  [cubana, americana, italiana]
# 197           media       [criolla, internacional]
#
#                                               services  \
# 0    {'plant': True, 'child_care': True, 'disable_s...
# 1    {'plant': False, 'child_care': False, 'disable...
# 2    {'plant': True, 'child_care': False, 'disable_...
# 3    {'plant': False, 'child_care': False, 'disable...
# 4    {'plant': True, 'child_care': True, 'disable_s...
# ..                                                 ...
# 193  {'plant': False, 'child_care': False, 'disable...
# 194  {'plant': True, 'child_care': True, 'disable_s...
# 195  {'plant': True, 'child_care': True, 'disable_s...
# 196  {'plant': True, 'child_care': True, 'disable_s...
# 197  {'plant': False, 'child_care': False, 'disable...
#
#                              pay_meth  \
# 0    {'cash': True, 'transfer': True}
# 1    {'cash': True, 'transfer': True}
# 2    {'cash': True, 'transfer': True}
# 3    {'cash': True, 'transfer': True}
# 4    {'cash': True, 'transfer': True}
# ..                                ...
# 193  {'cash': True, 'transfer': True}
# 194  {'cash': True, 'transfer': True}
# 195  {'cash': True, 'transfer': True}
# 196  {'cash': True, 'transfer': True}
# 197  {'cash': True, 'transfer': True}
#
#                                                   menu
# 0    {'breakfasts': {'items': [{'name': 'desayuno e...
# 1    {'breakfasts': False, 'appetizers': {'items': ...
# 2    {'breakfasts': False, 'appetizers': {'items': ...
# 3    {'breakfasts': False, 'appetizers': {'items': ...
# 4    {'breakfasts': {'items': [{'name': 'desayuno d...
# ..                                                 ...
# 193  {'breakfasts': False, 'appetizers': {'items': ...
# 194  {'breakfasts': False, 'appetizers': {'items': ...
# 195  {'breakfasts': {'items': [{'name': 'desayuno v...
# 196  {'breakfasts': {'items': [{'name': 'combo 1', ...
# 197  {'breakfasts': False, 'appetizers': {'items': ...
#
# [198 rows x 12 columns]

# %% [markdown]
# El grupo selecciono tres municipios cabacera por ser los mas frecuentados por ellos, de estos tres municipios analizaron 30 establecimientos, y del resto solo 10. Todos estos fueron clasificados en "bar", "restaurante" o "bar - restaurante"

# %%
# Contar los tipos de establecimientos
tipo_establecimientos = df['type_of_establishment'].value_counts().reset_index()
tipo_establecimientos.columns = ['Tipo de Establecimiento', 'Cantidad']

fig = px.pie(tipo_establecimientos, 
            values='Cantidad', 
            names='Tipo de Establecimiento', 
            title='Porcentaje de Tipos de Establecimientos en La Habana',
            hole=0.1)
fig.show()

# %%
# Crear un mapa con todos los establecimientos
mapa = folium.Map(location=[23.1136, -82.3666], zoom_start=12)  # Coordenadas de La Habana

for index, row in df.iterrows():
    latitude = row['coordinates']['latitude']
    longitude = row['coordinates']['longitude']
    name = row['name']
    
    folium.Marker(
        location=[latitude, longitude],
        popup=name,
        icon=folium.Icon(color='darkpurple')
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_266364d3b1d6f2c60bb8e1a8613c94e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_266364d3b1d6f2c60bb8e1a8613c94e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_266364d3b1d6f2c60bb8e1a8613c94e1 = L.map(
#                 &quot;map_266364d3b1d6f2c60bb8e1a8613c94e1&quot;,
#                 {
#                     center: [23.1136, -82.3666],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08374f01a5cdf85767d1f3e699c68356 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08374f01a5cdf85767d1f3e699c68356.addTo(map_266364d3b1d6f2c60bb8e1a8613c94e1);
#
#
#             var marker_007d33b0cdb6e28e63d2983e992cbe4f = L.marker(
#                 [23.12361712886297, -82.4271050650417],
#                 {
# }
#             ).addTo(map_266364d3b1d6f2c60bb8e1a8613c94e1);
#
#
#             var icon_0cfdc7f977fe6b2e4e89907420911268 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkpurple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_007d33b0cdb6e28e63d2983e992cbe4f.setIcon(icon_0cfdc7f977fe6b2e4e89907420911268);
#
#
#         var popup_1641c33e3971916af5d3a55fb8da2714 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91e2f451b51ebb7ccc6ed6e2a405266d = $(`&lt;div id=&quot;html_91e2f451b51ebb7ccc6ed6e2a405266d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;28 y Mar&lt;/div&gt;`)[0];
#                 popup_1641c33e3971916af5d3a55fb8da2714.setContent(html_91e2f451b51ebb7ccc6ed6e2a405266d);
#
#
#
#         marker_007d33b0cdb6e28e63d2983e992cbe4f.bindPopup(popup_1641c33e3971916af5d3a55fb8da2714)
#         ;
#
#
#
#
#             var marker_53ea0132a8d883faede0c664c7633eaa = L.marker(
#                 [23.12805874474967, -82.33435589367647],
#                 {
# }
#             ).addTo(map_266364d3b1d6f2c60bb8e1a8613c94e1);
#
#
#             var icon_ca876ffab56f4a413a576f5048554824 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkpurple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_53ea0132a8d883faede0c664c7633eaa.setIcon(icon_ca876ffab56f4a413a576f5048554824);
#
#
#         var popup_8a7087b1884981fc6afb2e1559f10bdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4deb7541df5af2d9d791bc5f0acbe04a = $(`&lt;div id=&quot;html_4deb7541df5af2d9d791bc5f0acbe04a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2KFÉ&lt;/div&gt;`)[0];
#                 popup_8a7087b1884981fc6afb2e1559f10bdc.setContent(html_4deb7541df5af2d9d791bc5f0acbe04a);
#
#
#
#         marker_53ea0132a8d883faede0c664c7633eaa.bindPopup(popup_8a7087b1884981fc6afb2e1559f10bdc)
#         ;
#
#
#
#
#             var marker_d11edd3994424554e91f96c686e73bdb = L.marker(
#                 [23.12374503719618, -82.32320046326254],
#                 {
# }
#             ).addTo(map_266364d3b1d6f2c60bb8e1a8613c94e1);
#
#
#             var icon_6f8e9d577093b187ce495841a90614ad = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkpurple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_d11edd3994424554e91f96c686e73bdb.setIcon(icon_6f8e9d577093b187ce495841a90614ad);
#
#
#         var popup_fe93a106db57acd5983edb730d641bb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3d3861a029b31838e1ba58af5ce9835 = $(`&lt;div id=&quot;html_c3d3861a029b31838e1ba58af5ce9835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;5ta Billar&lt;/div&gt;`)[0];
#                 popup_fe93a106db57acd5983edb730d641bb2.setContent(html_c3d3861a029b31838e1ba58af5ce9835);
#
#
#
#         marker_d11edd3994424554e91f96c686e73bdb.bindPopup(popup_fe93a106db57acd5983edb730d641bb2)
#         ;
#
#
#
#
#             var marker_1954d3e34db7e6c3f01b6a3f2bc0ea59 = L.marker(
#                 [23.07275737968528, -82.43208755151812],
#                 {
# }
#             ).addTo(map_266364d3b1d6f2c60bb8e1a8613c94e1);
#
#
#             var icon_b789ded04aa0382b7ed2c18f4ddf8947 = L.AwesomeMarkers.icon(

# %% [markdown]
# Uno de los aspectos que consideraron de mayor importancia, principalmente para los mas jovenes, fue el analisis sobre cuantos establecimientos de los estudiados poseia redes sociales como Instagran y Facebook que, por lo general influye en la popularidad del mismo.

# %%
#Ver la cantidad de establecimientos por municipio que tiene Instagram y Facebook.
def social_networks(contact):
    return bool(contact.get('instagram')) and bool(contact.get('facebook'))

df['has_social_net'] = df['contact'].apply(social_networks)

df_social_net = df[df['has_social_net']]

mun_count = df_social_net['district'].value_counts().reset_index()
mun_count.columns = ['Municipio', 'Cantidad']

fig = px.bar(mun_count, 
            x='Municipio', 
            y='Cantidad', 
            title='Cantidad de Restaurantes con Redes Sociales por Municipio',
            labels={'Cantidad': 'Cantidad de Restaurantes', 'Municipio': 'Municipio'},
            color='Cantidad',
            color_continuous_scale=px.colors.sequential.Purples)  # Cambiado a 'Greens'

fig.update_layout(xaxis_tickangle=-45)  # Rotar las etiquetas del eje x
fig.show()

# %%
df[df["rating"].isna()]=0
df_valid_ratings = df.sort_values(by='rating', ascending=False).head(20)  # Mostrar solo los 20 mejores

plt.figure(figsize=(15, 8))
plt.barh(df_valid_ratings['name'], df_valid_ratings['rating'], color='purple')
plt.title('Top 20 Ratings de Establecimientos en La Habana', fontsize=16)
plt.xlabel('Rating', fontsize=15)
plt.ylabel('Restaurantes', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=18)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_11828\2627492238.py:1: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.

# %%
df_sorted_values = df.sort_values(by='rating', ascending=False).tail(51) 
veinte_peores = df_sorted_values.iloc[:20,:]
print(veinte_peores)

plt.figure(figsize=(15, 8)) 
plt.barh(veinte_peores['name'], veinte_peores['rating'], color='purple')
plt.title('Top 20 Restaurantes con Peor Rating en La Habana', fontsize=16)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Restaurantes', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=18)
plt.tight_layout() 
plt.show()
# Out:
#     type_of_establishment                  name                district  \
# 196           restaurante                  Wapa  Plaza de la Revolución
# 104           restaurante         Joe's Burguer         Diez de Octubre
# 6             restaurante          Al Campestre         Habana del Este
# 85            restaurante          Fénix Dorado           Centro Habana
# 134     bar - restaurante  La ruta de Hemingway         Habana del Este
# 68      bar - restaurante              El Bleko           Centro Habana
# 24      bar - restaurante          Cafe Bulevar           Centro Habana
# 151           restaurante               Mokalex                   Playa
# 94            restaurante            Guang Zhou           Centro Habana
# 51            restaurante          Doping pizza           Centro Habana
# 130           restaurante              La Novia                 La Lisa
# 180     bar - restaurante            Shapuseros                   Cerro
# 176     bar - restaurante            Salsa Mora                   Playa
# 183           restaurante          Tong Do Laug           Centro Habana
# 43            restaurante                D'Mitu         Diez de Octubre
# 172           restaurante             Rico Rico                   Cerro
# 120     bar - restaurante             La Pelota  Plaza de la Revolución
# 80            restaurante            El Tráfico   San Miguel del Padrón
# 129           restaurante          La Mia Pizza                 La Lisa
# 48      bar - restaurante         Don Balbino's   San Miguel del Padrón
#
#                                            coordinates  \
# 196  {'latitude': 23.133054069126786, 'longitude': ...
# 104  {'latitude': 23.08829101929028, 'longitude': -...
# 6    {'latitude': 23.155282399334702, 'longitude': ...
# 85   {'latitude': 23.134776558921473, 'longitude': ...
# 134  {'latitude': 23.167411943757887, 'longitude': ...
# 68   {'latitude': 23.141509790555908, 'longitude': ...
# 24   {'latitude': 23.136606572526283, 'longitude': ...
# 151  {'latitude': 23.11213749973173, 'longitude': -...
# 94   {'latitude': 23.134985027583145, 'longitude': ...
# 51   {'latitude': 23.13389533564469, 'longitude': -...
# 130  {'latitude': 23.025201021634437, 'longitude': ...
# 180  {'latitude': 23.117562853692327, 'longitude': ...
# 176  {'latitude': 23.11402909851061, 'longitude': -...
# 183  {'latitude': 23.134994228631488, 'longitude': ...
# 43   {'latitude': 23.08648320188595, 'longitude': -...
# 172  {'latitude': 23.12627363995597, 'longitude': -...
# 120  {'latitude': 23.127810894630507, 'longitude': ...
# 80   {'latitude': 23.08023772075543, 'longitude': -...
# 129  {'latitude': 23.07138320836101, 'longitude': -...
# 48   {'latitude': 23.096667207456722, 'longitude': ...
#
#                                                contact  \
# 196  {'phone_number': '78314553', 'e-mail': 'info@w...
# 104  {'phone_number': '76400715', 'e-mail': 'roxybb...
# 6    {'phone_number': '77657743', 'e-mail': False, ...
# 85   {'phone_number': False, 'e-mail': False, 'web_...
# 134  {'phone_number': False, 'e-mail': False, 'web_...
# 68   {'phone_number': False, 'e-mail': False, 'web_...
# 24   {'phone_number': False, 'e-mail': False, 'web_...
# 151  {'phone_number': False, 'e-mail': False, 'web_...
# 94   {'phone_number': '78615229', 'e-mail': False, ...
# 51   {'phone_number': False, 'e-mail': False, 'web_...
# 130  {'phone_number': False, 'e-mail': False, 'web_...
# 180  {'phone_number': False, 'e-mail': False, 'web_...
# 176  {'phone_number': False, 'e-mail': False, 'web_...
# 183  {'phone_number': False, 'e-mail': False, 'web_...
# 43   {'phone_number': '76988258', 'e-mail': False, ...
# 172  {'phone_number': '78701632', 'e-mail': False, ...
# 120  {'phone_number': False, 'e-mail': False, 'web_...
# 80   {'phone_number': False, 'e-mail': False, 'web_...
# 129  {'phone_number': '72718614', 'e-mail': False, ...
# 48   {'phone_number': False, 'e-mail': False, 'web_...
#
#                                               schedule  rating  \
# 196  {'monday': {'open': '1130', 'close': '2300'}, ...     3.5
# 104  {'monday': {'open': '0800', 'close': '2200'}, ...     3.5
# 6    {'monday': {'open': '1000', 'close': '2200'}, ...     3.5
# 85   {'monday': {'open': '1100', 'close': '2300'}, ...     3.5
# 134  {'monday': {'open': '1200', 'close': '2300'}, ...     3.5
# 68   {'monday': {'open': '1300', 'close': '0200'}, ...     3.5
# 24   {'monday': {'open': '1100', 'close': '2300'}, ...     3.4
# 151  {'monday': {'open': False, 'close': False}, 't...     3.3
# 94   {'monday': {'open': '1100', 'close': '2400'}, ...     3.1
# 51   {'monday': {'open': '1200', 'close': '2400'}, ...     3.1
# 130  {'monday': {'open': '1200', 'close': '2400'}, ...     3.0
# 180  {'monday': {'open': '0900', 'close': '2100'}, ...     3.0
# 176  {'monday': {'open': '1100', 'close': '0400'}, ...     3.0
# 183  {'monday': {'open': '1000', 'close': '2100'}, ...     2.8
# 43   {'monday': {'open': '1000', 'close': '2200'}, ...     2.5
# 172  {'monday': {'open': '0900', 'close': '2300'}, ...     2.4
# 120  {'monday': {'open': '0945', 'close': '2145'}, ...     2.3
# 80   {'monday': {'open': '1000', 'close': '2200'}, ...     2.0
# 129  {'monday': {'open': '1100', 'close': '2300'}, ...     1.5
# 48   {'monday': {'open': '0830', 'close': '2300'}, ...     1.0
#
#     intake_capacity                                      cuisine  \
# 196           media                [cubana, americana, italiana]
# 104            baja                                  [americana]
# 6              alta                  [criolla, cubana, italiana]
# 85            media  [italiana, china, caribeña, cajún, criolla]
# 134           media                            [criolla, cubana]
# 68            media                [caribeña, italiana, criolla]
# 24             alta                                     [cubana]
# 151           media                              [internacional]
# 94            media                              [china, cubana]
# 51             baja                                   [italiana]
# 130           media                           [cubana, italiana]
# 180            baja                                  [americana]
# 176            alta                              [internacional]
# 183           media                                      [china]
# 43             baja                                   [italiana]
# 172            baja                                   [italiana]
# 120            baja                      [cubana, internacional]
# 80            media                          [criolla, italiana]
# 129            baja                                   [italiana]
# 48             alta                     [criolla, internacional]
#
#                                               services  \
# 196  {'plant': True, 'child_care': True, 'disable_s...
# 104  {'plant': False, 'child_care': False, 'disable...
# 6    {'plant': None, 'child_care': True, 'disable_s...
# 85   {'plant': False, 'child_care': False, 'disable...
# 134  {'plant': True, 'child_care': False, 'disable_...
# 68   {'plant': False, 'child_care': False, 'disable...
# 24   {'plant': False, 'child_care': False, 'disable...
# 151  {'plant': True, 'child_care': False, 'disable_...
# 94   {'plant': False, 'child_care': False, 'disable...
# 51   {'plant': False, 'child_care': False, 'disable...
# 130  {'plant': True, 'child_care': True, 'disable_s...
# 180  {'plant': True, 'child_care': False, 'disable_...
# 176  {'plant': True, 'child_care': False, 'disable_...
# 183  {'plant': False, 'child_care': False, 'disable...
# 43   {'plant': None, 'child_care': False, 'disable_...
# 172  {'plant': False, 'child_care': False, 'disable...
# 120  {'plant': False, 'child_care': False, 'disable...
# 80   {'plant': True, 'child_care': True, 'disable_s...
# 129  {'plant': False, 'child_care': True, 'disable_...
# 48   {'plant': False, 'child_care': True, 'disable_...
#
#                               pay_meth  \
# 196   {'cash': True, 'transfer': True}
# 104   {'cash': True, 'transfer': True}
# 6     {'cash': True, 'transfer': True}
# 85    {'cash': True, 'transfer': True}
# 134   {'cash': True, 'transfer': True}
# 68    {'cash': True, 'transfer': True}
# 24    {'cash': True, 'transfer': True}
# 151   {'cash': True, 'transfer': True}
# 94    {'cash': True, 'transfer': True}
# 51    {'cash': True, 'transfer': True}
# 130   {'cash': True, 'transfer': True}
# 180   {'cash': True, 'transfer': True}
# 176   {'cash': True, 'transfer': True}
# 183   {'cash': True, 'transfer': True}
# 43    {'cash': True, 'transfer': True}
# 172   {'cash': True, 'transfer': True}
# 120  {'cash': True, 'transfer': False}
# 80    {'cash': True, 'transfer': True}
# 129   {'cash': True, 'transfer': True}
# 48    {'cash': True, 'transfer': True}
#
#                                                   menu has_social_net
# 196  {'breakfasts': {'items': [{'name': 'combo 1', ...           True
# 104  {'breakfasts': False, 'appetizers': False, 'ma...           True
# 6    {'breakfasts': False, 'appetizers': {'items': ...           True
# 85   {'breakfasts': False, 'appetizers': {'items': ...          False
# 134  {'breakfasts': False, 'appetizers': {'items': ...          False
# 68   {'breakfasts': False, 'appetizers': {'items': ...           True
# 24   {'breakfasts': False, 'appetizers': {'items': ...          False
# 151  {'breakfasts': False, 'appetizers': {'items': ...           True
# 94   {'breakfasts': False, 'appetizers': {'items': ...          False
# 51   {'breakfasts': False, 'appetizers': {'items': ...          False
# 130  {'breakfasts': False, 'appetizers': {'items': ...           True
# 180  {'breakfasts': False, 'appetizers': False, 'ma...          False
# 176  {'breakfasts': False, 'appetizers': {'items': ...           True
# 183  {'breakfasts': False, 'appetizers': False, 'ma...          False
# 43   {'breakfasts': False, 'appetizers': False, 'ma...           True
# 172  {'breakfasts': False, 'appetizers': {'items': ...           True
# 120  {'breakfasts': False, 'appetizers': {'items': ...          False
# 80   {'breakfasts': False, 'appetizers': {'items': ...          False
# 129  {'breakfasts': False, 'appetizers': {'items': ...          False
# 48   {'breakfasts': False, 'appetizers': {'items': ...          False
